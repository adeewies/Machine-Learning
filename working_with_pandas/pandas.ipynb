# %%
import pandas as pd 
import numpy as np

# %%
data= pd.read_csv('V5.csv')

# %%
data.shape
# Out:
# (10000, 12)

# %%
# function to count question mark in the dataset
def countQuestionMark(x):
    return str(x).count('?')
counts = data.map(countQuestionMark)
print(counts.values.sum())
# Out:
# 1823

# %%
# checking value at a particular index for eample row 692 and col 0

data.iloc[692, 0]
# Out:
# '2009-11-16'

# %%
print(data.iloc[546, 7])
# Out:
# 3

# %%
# Replacing ? in the data with NaN
data.replace('?', np.nan, inplace=True)

# %%
data.Locality.unique()
# Out:
# array(['Waterbury', 'Bridgeport', 'Greenwich', 'Norwalk', nan,
#        'Fairfield', 'West Hartford', 'Stamford'], dtype=object)

# %%
data.isnull().sum()
# Out:
# Date                    0
# Year                    0
# Locality             1253
# Estimated Value      1243
# Sale Price              0
# Property             1823
# Residential             0
# num_rooms               0
# num_bathrooms           0
# carpet_area          1229
# property_tax_rate       0
# Face                    0
# dtype: int64

# %%
# droping rows based on  threshold value
data_cleaned_threshold = data.dropna(thresh=data.shape[1] - 2)

# %%
data_cleaned_threshold.shape
# Out:
# (9917, 12)

# %%
data_cleaned = data.dropna()

# %%
data_cleaned.shape
# Out:
# (5449, 12)

# %%
# Select all even index rows
even_indexed_rows = data.iloc[::2]

# %%
value = even_indexed_rows.iloc[332, 3]

# %%
print(value)
# Out:
# 256200.0

# %%
odd_indexed_rows = data.iloc[1::2]

# %%
value_odd = odd_indexed_rows.iloc[100, 5]

# %%
print(value_odd)
# Out:
# Single Family

# %%
even_rows_even_cols = data.iloc[::2, ::2]

# %%
value_odd_even = even_rows_even_cols.iloc[255, 3]

# %%
print(value_odd_even)
# Out:
# Detached House

# %%
# Filter rows where num_rooms = 3 or num_bathrooms = 3
filtered_df = data[(data['num_rooms'] == 3) & (data['num_bathrooms'] == 3)]

# Get the number of samples (rows) in the filtered DataFrame
num_samples = filtered_df.shape[0]

# %%
print(num_samples)
# Out:
# 2730

# %%
filtered_df1 = data[
    (data['Year'] == 2022) &  # Year = 2022
    (data['Locality'] == 'Greenwich') &  # Locality = Greenwich
    (data['num_rooms'] == 3) &  # num_room = 3
    (data['Face'].isin(['North', 'East']))  # Facing either North or East
]

# %%
num_houses = filtered_df1.shape[0]

# %%
print(num_houses)
# Out:
# 42

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
august_rows = data[data['Date'].dt.month == 8]

# %%
print(august_rows.shape)
# Out:
# (1050, 12)

# %%
avg_sale_price_by_locality = data.groupby('Locality')['Sale Price'].mean()

# %%
highest_avg_locality = avg_sale_price_by_locality.idxmax()
highest_avg_price = avg_sale_price_by_locality.max()

# %%
highest_avg_locality
# Out:
# 'Greenwich'

# %%
highest_avg_price
# Out:
# np.float64(2270223.539495238)

# %%
avg_sale_price_by_locality
# Out:
# Locality
# Bridgeport       1.740953e+05
# Fairfield        7.277225e+05
# Greenwich        2.270224e+06
# Norwalk          5.590959e+05
# Stamford         6.305313e+05
# Waterbury        1.062152e+05
# West Hartford    3.385472e+05
# Name: Sale Price, dtype: float64

# %%
from sklearn.datasets import fetch_california_housing

# %%
import numpy

# %%
import numpy

print(numpy.__version__)
# Out:
# 1.26.4

# %%
housing_data = fetch_california_housing()

# %%
print(housing_data.data.shape)
# Out:
# (20640, 8)

# %%
import pandas as pd

# %%
data= pd.read_csv("data.csv")

# %%
data.head()
# Out:
#          Date      Vch/Bill No                    Customer Name  \
# 0  01-08-2024  VDS/S/204/24-25     BEUMER INDIA PRIVATE LIMITED
# 1  01-08-2024  VDS/S/205/24-25      MBL INFRASTRUCTURES LIMITED
# 2  01-08-2024  VDS/S/205/24-25  RANJEET CRANE & TRAILER SERVICE
# 3  01-08-2024  VDS/S/205/24-25  RANJEET CRANE & TRAILER SERVICE
# 4  01-08-2024  VDS/S/205/24-25  RANJEET CRANE & TRAILER SERVICE
#
#                        Service Part Name  Qty.   Unit    Price  Amount  \
# 0                   W.C.ASSY SK860290320  1.00  UNITS  1784.00  1784.0
# 1                        SERVICE CHARGES   Nil   N.A.      Nil  6000.0
# 2  CLUTCH ASSY ST. AXLE  S7203206AS0 28%  1.00  UNITS  4271.00  4271.0
# 3     BEARING CLUTCH RELEASE SK100053900  1.00  UNITS   747.00   747.0
# 4               BALL BEARING SK220776500  1.00  UNITS   121.00   121.0
#
#    Unnamed: 8  Stock  Reorder Point Last Received Material  \
# 0         NaN     47             22             2024-09-26
# ...

# %%
import numpy as np
data['Stock'] = np.random.randint(5, 50, size=len(data))

# %%
data['Reorder Point'] = np.random.randint(10, 30, size=len(data))

# %%
data['Last Received Material'] = pd.to_datetime(
    np.random.choice(pd.date_range(start=pd.Timestamp('2024-08-01'), end=pd.Timestamp('2024-10-31')), size=len(data))
)

# %%
data['Customer Satisfaction Rating'] = np.random.randint(4, 11, size=len(data))

# %%
#data.to_csv('t_data.csv')

# %%
t_data= pd.read_csv('t_data.csv')

# %%
t_data
# Out:
#            Date      Vch/Bill No                      Customer Name  \
# 0    01-08-2024  VDS/S/204/24-25       BEUMER INDIA PRIVATE LIMITED
# 1    01-08-2024  VDS/S/205/24-25        MBL INFRASTRUCTURES LIMITED
# 2    01-08-2024  VDS/S/205/24-25    RANJEET CRANE & TRAILER SERVICE
# 3    01-08-2024  VDS/S/205/24-25    RANJEET CRANE & TRAILER SERVICE
# 4    01-08-2024  VDS/S/205/24-25    RANJEET CRANE & TRAILER SERVICE
# ..          ...              ...                                ...
# 506  29-10-2024  VDS/S/404/24-25                    SATYENDRA SINGH
# 507  29-10-2024  VDS/S/404/24-25                    SATYENDRA SINGH
# 508  30-10-2024  VDS/S/412/24-25       YD BUILDERS & HOTELS PVT LTD
# 509  30-10-2024  VDS/S/413/24-25  SHRI RADHEY MINES PRIVATE LIMITED
# 510  30-10-2024  VDS/S/413/24-25  SHRI RADHEY MINES PRIVATE LIMITED
#
#                             Service Part Name  Qty.   Unit   Price  Amount  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure that the Amount column is numeric (in case it's read as a string)
t_data['Amount'] = pd.to_numeric(t_data['Amount'], errors='coerce')

# Create a violin plot for 'Amount' by 'Customer Satisfaction Rating'
plt.figure(figsize=(12, 6))
sns.violinplot(x='Customer Satisfaction Rating', y='Amount', data=t_data, palette='viridis')

# Add title and labels
plt.title('Violin Chart of Sales Amount by Customer Satisfaction Rating')
plt.xlabel('Customer Satisfaction Rating')
plt.ylabel('Sales Amount')

# Show plot
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_32260\1146436640.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Customer Satisfaction Rating', y='Amount', data=t_data, palette='viridis')

# %%
import squarify
import matplotlib.pyplot as plt

# Prepare the data for the treemap
# Group data by 'Customer Name' and aggregate sales and satisfaction ratings
customer_sales_data = t_data.groupby('Customer Name').agg({
    'Amount': 'sum',
    'Customer Satisfaction Rating': 'mean'
}).reset_index()

# Sort by 'Amount' to ensure larger sales are represented first
customer_sales_data = customer_sales_data.sort_values(by='Amount', ascending=False)

# Create a treemap
plt.figure(figsize=(16, 10))
squarify.plot(
    sizes=customer_sales_data['Amount'],
    label=customer_sales_data['Customer Name'],
    color=plt.cm.viridis(customer_sales_data['Customer Satisfaction Rating'] / customer_sales_data['Customer Satisfaction Rating'].max()),
    alpha=0.8
)

# Add title and format the plot
plt.title('Treemap of Sales by Customer and Satisfaction Rating')
plt.axis('off')  # Remove axis
plt.show()

# %%
import squarify
import matplotlib.pyplot as plt

# Prepare the data for the treemap
# Group data by 'Customer Name' and aggregate sales and satisfaction ratings
customer_sales_data = t_data.groupby('Customer Name').agg({
    'Amount': 'sum',
    'Customer Satisfaction Rating': 'mean'
}).reset_index()

# Sort by 'Amount' and select the top 20 customers
top_20_customers = customer_sales_data.sort_values(by='Amount', ascending=False).head(10)

# Create a treemap for the top 20 customers
plt.figure(figsize=(16, 10))
squarify.plot(
    sizes=top_20_customers['Amount'],
    label=top_20_customers['Customer Name'],
    color=plt.cm.viridis(top_20_customers['Customer Satisfaction Rating'] / top_20_customers['Customer Satisfaction Rating'].max()),
    alpha=0.8
)

# Add title and format the plot
plt.title('Treemap of Top 10 Customers by Sales and Satisfaction Rating')
plt.axis("off")  # Remove axis
plt.show()

# %%
# Correlation matrix
correlation_matrix = t_data[['Amount', 'Customer Satisfaction Rating', 'Stock Value', 'Reorder Point', 'Price']].corr()
print(correlation_matrix)

# Optional: Visualize the correlation matrix
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
# Out:
#                                 Amount  Customer Satisfaction Rating  \
# Amount                        1.000000                      0.218811
# Customer Satisfaction Rating  0.218811                      1.000000
# Stock Value                   0.838436                      0.138845
# Reorder Point                -0.060989                     -0.036149
# Price                         0.977528                      0.174572
#
#                               Stock Value  Reorder Point     Price
# Amount                           0.838436      -0.060989  0.977528
# Customer Satisfaction Rating     0.138845      -0.036149  0.174572
# Stock Value                      1.000000      -0.005673  0.951889
# Reorder Point                   -0.005673       1.000000 -0.030143
# Price                            0.951889      -0.030143  1.000000

# %%
t_data.describe()
# Out:
#              Qty.          Price         Amount       Stock   Stock Value  \
# count  477.000000     477.000000     511.000000  511.000000  5.110000e+02
# mean     2.067086    3811.774403    4956.443757   26.978474  9.918314e+04
# std      4.654864   13614.158643   14807.307038   12.809522  4.533493e+05
# min      1.000000       2.000000       3.000000    5.000000  0.000000e+00
# 25%      1.000000     365.540000     500.000000   16.000000  5.694650e+03
# 50%      1.000000    1271.000000    1783.150000   26.000000  2.497600e+04
# 75%      2.000000    3122.000000    3803.000000   38.000000  7.955288e+04
# max     65.000000  175175.000000  175175.000000   49.000000  7.021916e+06
#
#        Reorder Point  Customer Satisfaction Rating
# count     511.000000                    511.000000
# mean       19.782779                      8.080235
# std         5.641042                      1.231698
# min        10.000000                      5.000000
# ...

# %%
import squarify
import matplotlib.pyplot as plt

# Prepare the data for the treemap
# Group data by 'Customer Name' and aggregate sales and satisfaction ratings
customer_sales_data = t_data.groupby('Customer Name').agg({
    'Amount': 'sum',
    'Customer Satisfaction Rating': 'mean'
}).reset_index()

# Sort by 'Amount' and select the top 20 customers
top_20_customers = customer_sales_data.sort_values(by='Amount', ascending=False).tail(20)

# Create a treemap for the top 20 customers
plt.figure(figsize=(16, 10))
squarify.plot(
    sizes=top_20_customers['Amount'],
    label=top_20_customers['Customer Name'],
    color=plt.cm.viridis(top_20_customers['Customer Satisfaction Rating'] / top_20_customers['Customer Satisfaction Rating'].max()),
    alpha=0.6
)

# Add title and format the plot
plt.title('Treemap of bottom 20 Customers by Sales and Satisfaction Rating')
plt.axis()  # Remove axis
plt.show()
